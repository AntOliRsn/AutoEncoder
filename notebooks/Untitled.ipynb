# %%
import numpy as np
import pandas as pd
import os 
from matplotlib import pyplot as plt

# %%
main_path = "/home/antorosi/Documents/AutoEncoder/out"
path_thesis_figures = '/home/antorosi/Documents/Thesis/Figures'
path_result = os.path.join(main_path, 'benchmark_cae_1')
name_doc = "main_results.csv"

# %%
result_df = pd.read_csv(os.path.join(path_result,name_doc), sep=";")

# %%
x = result_df['z_dim']
y= result_df['test_mse']

# %%
plt.figure(figsize=(8,5))
plt.plot(x,y,'-o')
plt.ylabel("Reconstruction error [MSE]", size=14)
plt.xlabel("Latent space dimension",size=14)

name_fig = 'CAE_z_dim_ev'
plt.savefig(os.path.join(path_thesis_figures, name_fig + '.png'))
plt.savefig(os.path.join(path_thesis_figures, name_fig + '.pdf'))
