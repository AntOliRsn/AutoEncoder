# %% [markdown]
# ### Library

# %%
import sys
import os
import datetime
import pandas as pd
import numpy as np
import pickle
from matplotlib import pyplot as plt
import seaborn as sn
from scipy import stats

path_main_folder = '/home/antorosi/Documents/AutoEncoder'

sys.path.append(path_main_folder)

from CVAE.cvae import compile_cvae, run_cvae
from CVAE.cvae_model import CVAE
from conso.load_shape_data import *  
from conso.conso_helpers import plot_latent_space_projection, pyplot_latent_space_projection_temp, pyplot_latent_space_projection_error

# %% [markdown]
# ### Load and shape data

# %%
# Load raw data
path_data = os.path.join(path_main_folder, 'data')
dict_data_conso = load_data_conso(path_data)

# %%
# Load Holiday day information
holiday_days_csv = os.path.join(path_data, "joursFeries.csv")
holiday_days_df = pd.read_csv(holiday_days_csv, sep=";")
holiday_days_df.ds = pd.to_datetime(holiday_days_df.ds)
holiday_days_df['is_hd'] = 1

# %%
# Unifomization
data_conso_df, dict_colnames_conso = get_uniformed_data_conso(dict_data_conso)

# %%
# Change ganularity ?
name_granu = '30m'
data_conso_df = change_granularity(data_conso_df, granularity="30min")

# %%
# Get x_conso dataframe for autoencoder purpose
x_conso = get_x_conso_autoencoder(data_conso_df, dict_colnames_conso)

# %% [markdown]
# ### Build dataset

# %%
# Split train and test
#date_test_start = datetime.date(2014,1,1)
#date_test_end = datetime.date(2015,1,1)
#dict_xconso = get_train_test_x_conso(x_conso, date_test_start, date_test_end)

dict_xconso = {'train': x_conso}

# %%
# Normalize x_conso
type_scaler = 's'
dict_xconso = normalize_xconso(dict_xconso, dict_colnames_conso, type_scaler = 'standard')

# %%
name_type_cond = 'm-wd'
name_train = '0' # 1: first period ; 0 all periods
name_type_x = 'c-temp'
type_x = ['conso', 'temperature']
type_cond = ['month', 'weekday']

# %%
dataset = get_dataset_autoencoder(dict_xconso=dict_xconso, type_x=type_x, type_cond=type_cond)

# %%
dataset['train']['x'][0].shape
# Out:
# (1830, 96)

# %% [markdown]
# ### Build model

# %%
path_out = os.path.join(path_main_folder, 'out')

# %%
# Parameters
cond_dim = dataset['train']['x'][1].shape[1]
e_dims=[48,24,12]
d_dims=[12,24,48]
z_dim= 2
beta = 0.6

# %%
name_model = 'cvae_conso_e48-24-12_d12-24-48_gran-{}_x-{}_cond-{}'.format(name_granu,name_type_x, name_type_cond)

# %%
name_model
# Out:
# 'cvae_conso_e48-24-12_d12-24-48_gran-30m_x-c-temp_cond-m-wd'

# %%
model = CVAE(cond_dim=cond_dim, 
             e_dims=e_dims, 
             d_dims=d_dims, 
             z_dim=z_dim, 
             beta=beta,
             name=name_model, 
             output=path_out)
# Out:
# complete model:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# x_true (InputLayer)             (None, 96)           0
# __________________________________________________________________________________________________
# cond (InputLayer)               (None, 14)           0
# __________________________________________________________________________________________________
# encoder (Model)                 [(None, 2), (None, 2 6856        x_true[0][0]
#                                                                  cond[0][0]
# __________________________________________________________________________________________________
# sample_z (Lambda)               (None, 2)            0           encoder[1][0]
#                                                                  encoder[1][1]
# __________________________________________________________________________________________________
# decoder (Model)                 (None, 96)           6420        sample_z[0][0]
#                                                                  cond[0][0]
# ==================================================================================================
# Total params: 13,276
# Trainable params: 13,276
# Non-trainable params: 0
# __________________________________________________________________________________________________
# encoder:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# enc_x_true (InputLayer)         (None, 96)           0
# __________________________________________________________________________________________________
# enc_cond (InputLayer)           (None, 14)           0
# __________________________________________________________________________________________________
# enc_input (Concatenate)         (None, 110)          0           enc_x_true[0][0]
#                                                                  enc_cond[0][0]
# __________________________________________________________________________________________________
# enc_dense_0 (Dense)             (None, 48)           5328        enc_input[0][0]
# __________________________________________________________________________________________________
# enc_dense_1 (Dense)             (None, 24)           1176        enc_dense_0[0][0]
# __________________________________________________________________________________________________
# enc_dense_2 (Dense)             (None, 12)           300         enc_dense_1[0][0]
# __________________________________________________________________________________________________
# latent_dense_mu (Dense)         (None, 2)            26          enc_dense_2[0][0]
# __________________________________________________________________________________________________
# latent_dense_log_sigma (Dense)  (None, 2)            26          enc_dense_2[0][0]
# ==================================================================================================
# Total params: 6,856
# Trainable params: 6,856
# Non-trainable params: 0
# __________________________________________________________________________________________________
# decoder:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# dec_z (InputLayer)              (None, 2)            0
# __________________________________________________________________________________________________
# dec_cond (InputLayer)           (None, 14)           0
# __________________________________________________________________________________________________
# dec_input (Concatenate)         (None, 16)           0           dec_z[0][0]
#                                                                  dec_cond[0][0]
# __________________________________________________________________________________________________
# dec_dense_0 (Dense)             (None, 12)           204         dec_input[0][0]
# __________________________________________________________________________________________________
# dec_dense_1 (Dense)             (None, 24)           312         dec_dense_0[0][0]
# __________________________________________________________________________________________________
# dec_dense_2 (Dense)             (None, 48)           1200        dec_dense_1[0][0]
# __________________________________________________________________________________________________
# dec_x_hat (Dense)               (None, 96)           4704        dec_dense_2[0][0]
# ==================================================================================================
# Total params: 6,420
# Trainable params: 6,420
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Trainning model

# %%
model.main_train(dataset, training_epochs=200, batch_size=20, verbose=False)
# Out:
# --- START TRAINING ---
#
# Epoch 1/200
# 1830/1830 [==============================] - 0s 164us/step - loss: 40.5645 - kl_loss: 7.1350 - recon_loss: 36.2835
# Epoch 2/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 13.7332 - kl_loss: 5.1540 - recon_loss: 10.6408
# Epoch 3/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 10.8364 - kl_loss: 4.4733 - recon_loss: 8.1524
# Epoch 4/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 8.8246 - kl_loss: 4.3221 - recon_loss: 6.2313
# Epoch 5/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 7.5435 - kl_loss: 4.3195 - recon_loss: 4.9518
# Epoch 6/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 7.0394 - kl_loss: 4.3788 - recon_loss: 4.4121
# Epoch 7/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 6.5886 - kl_loss: 4.3436 - recon_loss: 3.9824
# Epoch 8/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 6.2318 - kl_loss: 4.2299 - recon_loss: 3.6939
# Epoch 9/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 6.0866 - kl_loss: 4.1912 - recon_loss: 3.5719
# Epoch 10/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 5.9709 - kl_loss: 4.1033 - recon_loss: 3.5089
# Epoch 11/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 5.9081 - kl_loss: 4.1443 - recon_loss: 3.4215
# Epoch 12/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 5.7183 - kl_loss: 4.0842 - recon_loss: 3.2678
# Epoch 13/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 5.6976 - kl_loss: 4.0124 - recon_loss: 3.2902
# Epoch 14/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 5.5639 - kl_loss: 3.9975 - recon_loss: 3.1654
# Epoch 15/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 5.5516 - kl_loss: 3.9491 - recon_loss: 3.1821
# Epoch 16/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 5.4717 - kl_loss: 3.9380 - recon_loss: 3.1089
# Epoch 17/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 5.4599 - kl_loss: 3.9100 - recon_loss: 3.1139
# Epoch 18/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 5.3142 - kl_loss: 3.8600 - recon_loss: 2.9981
# Epoch 19/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 5.2382 - kl_loss: 3.7844 - recon_loss: 2.9676
# Epoch 20/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 5.2991 - kl_loss: 3.8374 - recon_loss: 2.9966
# Epoch 21/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 5.1649 - kl_loss: 3.7754 - recon_loss: 2.8997
# Epoch 22/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 5.1785 - kl_loss: 3.7795 - recon_loss: 2.9108
# Epoch 23/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 5.1527 - kl_loss: 3.7558 - recon_loss: 2.8992
# Epoch 24/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 5.0823 - kl_loss: 3.6941 - recon_loss: 2.8659
# Epoch 25/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 5.0476 - kl_loss: 3.6946 - recon_loss: 2.8309
# Epoch 26/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.9467 - kl_loss: 3.5622 - recon_loss: 2.8094
# Epoch 27/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.9636 - kl_loss: 3.6127 - recon_loss: 2.7960
# Epoch 28/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 4.9112 - kl_loss: 3.5364 - recon_loss: 2.7894
# Epoch 29/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 4.8761 - kl_loss: 3.5912 - recon_loss: 2.7214
# Epoch 30/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 4.8638 - kl_loss: 3.5474 - recon_loss: 2.7354
# Epoch 31/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 4.8473 - kl_loss: 3.4936 - recon_loss: 2.7511
# Epoch 32/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 4.8464 - kl_loss: 3.5301 - recon_loss: 2.7284
# Epoch 33/200
# 1830/1830 [==============================] - 0s 67us/step - loss: 4.7561 - kl_loss: 3.4465 - recon_loss: 2.6882
# Epoch 34/200
# 1830/1830 [==============================] - 0s 65us/step - loss: 4.7820 - kl_loss: 3.4311 - recon_loss: 2.7234
# Epoch 35/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.7465 - kl_loss: 3.4280 - recon_loss: 2.6897
# Epoch 36/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 4.6870 - kl_loss: 3.3883 - recon_loss: 2.6540
# Epoch 37/200
# 1830/1830 [==============================] - 0s 63us/step - loss: 4.7393 - kl_loss: 3.4200 - recon_loss: 2.6873
# Epoch 38/200
# 1830/1830 [==============================] - 0s 66us/step - loss: 4.6765 - kl_loss: 3.3776 - recon_loss: 2.6499
# Epoch 39/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 4.6683 - kl_loss: 3.3651 - recon_loss: 2.6493
# Epoch 40/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.6528 - kl_loss: 3.3404 - recon_loss: 2.6486
# Epoch 41/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 4.6565 - kl_loss: 3.3541 - recon_loss: 2.6440
# Epoch 42/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 4.5921 - kl_loss: 3.2810 - recon_loss: 2.6235
# Epoch 43/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 4.6080 - kl_loss: 3.3034 - recon_loss: 2.6259
# Epoch 44/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 4.5930 - kl_loss: 3.3304 - recon_loss: 2.5948
# Epoch 45/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 4.5374 - kl_loss: 3.2164 - recon_loss: 2.6076
# Epoch 46/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.5556 - kl_loss: 3.2689 - recon_loss: 2.5943
# Epoch 47/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.5229 - kl_loss: 3.2165 - recon_loss: 2.5930
# Epoch 48/200
# 1830/1830 [==============================] - 0s 64us/step - loss: 4.4556 - kl_loss: 3.2003 - recon_loss: 2.5354
# Epoch 49/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 4.4609 - kl_loss: 3.1736 - recon_loss: 2.5568
# Epoch 50/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 4.4851 - kl_loss: 3.2106 - recon_loss: 2.5588
# Epoch 51/200
# 1830/1830 [==============================] - 0s 65us/step - loss: 4.4378 - kl_loss: 3.1202 - recon_loss: 2.5657
# Epoch 52/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.4620 - kl_loss: 3.1652 - recon_loss: 2.5628
# Epoch 53/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 4.4308 - kl_loss: 3.1779 - recon_loss: 2.5240
# Epoch 54/200
# 1830/1830 [==============================] - 0s 67us/step - loss: 4.4243 - kl_loss: 3.1309 - recon_loss: 2.5457
# Epoch 55/200
# 1830/1830 [==============================] - 0s 67us/step - loss: 4.4151 - kl_loss: 3.1766 - recon_loss: 2.5091
# Epoch 56/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 4.3996 - kl_loss: 3.1248 - recon_loss: 2.5247
# Epoch 57/200
# 1830/1830 [==============================] - 0s 66us/step - loss: 4.3454 - kl_loss: 3.0883 - recon_loss: 2.4924
# Epoch 58/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 4.3806 - kl_loss: 3.0756 - recon_loss: 2.5352
# Epoch 59/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 4.3653 - kl_loss: 3.1080 - recon_loss: 2.5006
# Epoch 60/200
# 1830/1830 [==============================] - 0s 76us/step - loss: 4.2963 - kl_loss: 3.0176 - recon_loss: 2.4857
# Epoch 61/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.3425 - kl_loss: 3.0809 - recon_loss: 2.4940
# Epoch 62/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.2703 - kl_loss: 2.9817 - recon_loss: 2.4812
# Epoch 63/200
# 1830/1830 [==============================] - 0s 66us/step - loss: 4.2678 - kl_loss: 3.0172 - recon_loss: 2.4575
# Epoch 64/200
# 1830/1830 [==============================] - 0s 67us/step - loss: 4.2943 - kl_loss: 3.0060 - recon_loss: 2.4907
# Epoch 65/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 4.2577 - kl_loss: 2.9789 - recon_loss: 2.4704
# Epoch 66/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 4.2587 - kl_loss: 3.0225 - recon_loss: 2.4452
# Epoch 67/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 4.2430 - kl_loss: 2.9653 - recon_loss: 2.4638
# Epoch 68/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 4.2082 - kl_loss: 2.9439 - recon_loss: 2.4419
# Epoch 69/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 4.2260 - kl_loss: 2.9441 - recon_loss: 2.4596
# Epoch 70/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 4.2501 - kl_loss: 3.0190 - recon_loss: 2.4387
# Epoch 71/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.1831 - kl_loss: 2.9060 - recon_loss: 2.4395
# Epoch 72/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 4.1680 - kl_loss: 2.9158 - recon_loss: 2.4185
# Epoch 73/200
# 1830/1830 [==============================] - 0s 78us/step - loss: 4.1843 - kl_loss: 2.9119 - recon_loss: 2.4371
# Epoch 74/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.1644 - kl_loss: 2.8910 - recon_loss: 2.4298
# Epoch 75/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.1441 - kl_loss: 2.8656 - recon_loss: 2.4248
# Epoch 76/200
# 1830/1830 [==============================] - 0s 76us/step - loss: 4.2042 - kl_loss: 2.9085 - recon_loss: 2.4591
# Epoch 77/200
# 1830/1830 [==============================] - 0s 77us/step - loss: 4.1591 - kl_loss: 2.9432 - recon_loss: 2.3932
# Epoch 78/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.1955 - kl_loss: 2.9090 - recon_loss: 2.4501
# Epoch 79/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 4.1299 - kl_loss: 2.9043 - recon_loss: 2.3874
# Epoch 80/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.1639 - kl_loss: 2.8664 - recon_loss: 2.4440
# Epoch 81/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.1348 - kl_loss: 2.8976 - recon_loss: 2.3963
# Epoch 82/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.1034 - kl_loss: 2.8359 - recon_loss: 2.4018
# Epoch 83/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.1461 - kl_loss: 2.8562 - recon_loss: 2.4324
# Epoch 84/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.0847 - kl_loss: 2.8483 - recon_loss: 2.3757
# Epoch 85/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.1089 - kl_loss: 2.8339 - recon_loss: 2.4086
# Epoch 86/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 4.0647 - kl_loss: 2.8466 - recon_loss: 2.3567
# Epoch 87/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 4.0658 - kl_loss: 2.7967 - recon_loss: 2.3877
# Epoch 88/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.0419 - kl_loss: 2.7829 - recon_loss: 2.3722
# Epoch 89/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.0507 - kl_loss: 2.7393 - recon_loss: 2.4071
# Epoch 90/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.0211 - kl_loss: 2.8381 - recon_loss: 2.3182
# Epoch 91/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.0013 - kl_loss: 2.7484 - recon_loss: 2.3523
# Epoch 92/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 4.0440 - kl_loss: 2.7935 - recon_loss: 2.3679
# Epoch 93/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.0167 - kl_loss: 2.7775 - recon_loss: 2.3502
# Epoch 94/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 4.0105 - kl_loss: 2.7758 - recon_loss: 2.3449
# Epoch 95/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.9902 - kl_loss: 2.7449 - recon_loss: 2.3433
# Epoch 96/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.9883 - kl_loss: 2.7253 - recon_loss: 2.3532
# Epoch 97/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.0321 - kl_loss: 2.7576 - recon_loss: 2.3776
# Epoch 98/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 4.0500 - kl_loss: 2.8163 - recon_loss: 2.3602
# Epoch 99/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 3.9935 - kl_loss: 2.7728 - recon_loss: 2.3298
# Epoch 100/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 3.9495 - kl_loss: 2.7367 - recon_loss: 2.3075
# Epoch 101/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 4.0139 - kl_loss: 2.7199 - recon_loss: 2.3819
# Epoch 102/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.9578 - kl_loss: 2.7400 - recon_loss: 2.3138
# Epoch 103/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.9665 - kl_loss: 2.7229 - recon_loss: 2.3327
# Epoch 104/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.9725 - kl_loss: 2.7316 - recon_loss: 2.3335
# Epoch 105/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.9267 - kl_loss: 2.6409 - recon_loss: 2.3422
# Epoch 106/200
# 1830/1830 [==============================] - 0s 86us/step - loss: 3.9140 - kl_loss: 2.6708 - recon_loss: 2.3115
# Epoch 107/200
# 1830/1830 [==============================] - 0s 99us/step - loss: 3.9345 - kl_loss: 2.6940 - recon_loss: 2.3181
# Epoch 108/200
# 1830/1830 [==============================] - 0s 95us/step - loss: 3.9310 - kl_loss: 2.6877 - recon_loss: 2.3183
# Epoch 109/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 3.9499 - kl_loss: 2.6926 - recon_loss: 2.3343
# Epoch 110/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.9437 - kl_loss: 2.6911 - recon_loss: 2.3290
# Epoch 111/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 3.9336 - kl_loss: 2.7141 - recon_loss: 2.3052
# Epoch 112/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.9249 - kl_loss: 2.6701 - recon_loss: 2.3229
# Epoch 113/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.9168 - kl_loss: 2.7123 - recon_loss: 2.2894
# Epoch 114/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 3.9690 - kl_loss: 2.6939 - recon_loss: 2.3527
# Epoch 115/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.8836 - kl_loss: 2.6901 - recon_loss: 2.2695
# Epoch 116/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 3.8939 - kl_loss: 2.6604 - recon_loss: 2.2976
# Epoch 117/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 3.9351 - kl_loss: 2.7355 - recon_loss: 2.2938
# Epoch 118/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 3.8794 - kl_loss: 2.6470 - recon_loss: 2.2912
# Epoch 119/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 3.8175 - kl_loss: 2.6111 - recon_loss: 2.2509
# Epoch 120/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.9034 - kl_loss: 2.6598 - recon_loss: 2.3076
# Epoch 121/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.8719 - kl_loss: 2.6660 - recon_loss: 2.2723
# Epoch 122/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 3.8589 - kl_loss: 2.6619 - recon_loss: 2.2617
# Epoch 123/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 3.8241 - kl_loss: 2.6191 - recon_loss: 2.2526
# Epoch 124/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 3.8616 - kl_loss: 2.6486 - recon_loss: 2.2725
# Epoch 125/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 3.8704 - kl_loss: 2.6391 - recon_loss: 2.2869
# Epoch 126/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.8689 - kl_loss: 2.6821 - recon_loss: 2.2596
# Epoch 127/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 3.8115 - kl_loss: 2.6281 - recon_loss: 2.2347
# Epoch 128/200
# 1830/1830 [==============================] - 0s 76us/step - loss: 3.7676 - kl_loss: 2.5794 - recon_loss: 2.2200
# Epoch 129/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.8167 - kl_loss: 2.5957 - recon_loss: 2.2593
# Epoch 130/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.8332 - kl_loss: 2.6646 - recon_loss: 2.2344
# Epoch 131/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.8269 - kl_loss: 2.6424 - recon_loss: 2.2414
# Epoch 132/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 3.8037 - kl_loss: 2.6588 - recon_loss: 2.2085
# Epoch 133/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.8094 - kl_loss: 2.5576 - recon_loss: 2.2748
# Epoch 134/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 3.8509 - kl_loss: 2.6853 - recon_loss: 2.2397
# Epoch 135/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.8315 - kl_loss: 2.6739 - recon_loss: 2.2272
# Epoch 136/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.7987 - kl_loss: 2.6115 - recon_loss: 2.2318
# Epoch 137/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.7810 - kl_loss: 2.6071 - recon_loss: 2.2168
# Epoch 138/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.7806 - kl_loss: 2.6104 - recon_loss: 2.2143
# Epoch 139/200
# 1830/1830 [==============================] - 0s 76us/step - loss: 3.8261 - kl_loss: 2.6123 - recon_loss: 2.2588
# Epoch 140/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.7739 - kl_loss: 2.5973 - recon_loss: 2.2156
# Epoch 141/200
# 1830/1830 [==============================] - 0s 76us/step - loss: 3.7779 - kl_loss: 2.6031 - recon_loss: 2.2160
# Epoch 142/200
# 1830/1830 [==============================] - 0s 76us/step - loss: 3.8327 - kl_loss: 2.6412 - recon_loss: 2.2480
# Epoch 143/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 3.7562 - kl_loss: 2.5801 - recon_loss: 2.2081
# Epoch 144/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.8135 - kl_loss: 2.6432 - recon_loss: 2.2276
# Epoch 145/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.8095 - kl_loss: 2.6420 - recon_loss: 2.2244
# Epoch 146/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 3.7931 - kl_loss: 2.5839 - recon_loss: 2.2428
# Epoch 147/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.7684 - kl_loss: 2.6026 - recon_loss: 2.2068
# Epoch 148/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.7953 - kl_loss: 2.6206 - recon_loss: 2.2229
# Epoch 149/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.7324 - kl_loss: 2.5705 - recon_loss: 2.1902
# Epoch 150/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.7711 - kl_loss: 2.5995 - recon_loss: 2.2114
# Epoch 151/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.7995 - kl_loss: 2.6323 - recon_loss: 2.2201
# Epoch 152/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.7770 - kl_loss: 2.6146 - recon_loss: 2.2083
# Epoch 153/200
# 1830/1830 [==============================] - 0s 66us/step - loss: 3.7509 - kl_loss: 2.5972 - recon_loss: 2.1926
# Epoch 154/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.7781 - kl_loss: 2.6317 - recon_loss: 2.1991
# Epoch 155/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.7119 - kl_loss: 2.5786 - recon_loss: 2.1647
# Epoch 156/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.7825 - kl_loss: 2.6296 - recon_loss: 2.2048
# Epoch 157/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 3.7533 - kl_loss: 2.5871 - recon_loss: 2.2011
# Epoch 158/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 3.7533 - kl_loss: 2.6239 - recon_loss: 2.1790
# Epoch 159/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.7750 - kl_loss: 2.6590 - recon_loss: 2.1796
# Epoch 160/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.7449 - kl_loss: 2.6046 - recon_loss: 2.1821
# Epoch 161/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.7455 - kl_loss: 2.5980 - recon_loss: 2.1867
# Epoch 162/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.7130 - kl_loss: 2.5712 - recon_loss: 2.1703
# Epoch 163/200
# 1830/1830 [==============================] - 0s 67us/step - loss: 3.7236 - kl_loss: 2.5790 - recon_loss: 2.1761
# Epoch 164/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 3.7659 - kl_loss: 2.6498 - recon_loss: 2.1760
# Epoch 165/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.7335 - kl_loss: 2.6117 - recon_loss: 2.1665
# Epoch 166/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.7011 - kl_loss: 2.5904 - recon_loss: 2.1469
# Epoch 167/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 3.7230 - kl_loss: 2.5843 - recon_loss: 2.1724
# Epoch 168/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 3.7381 - kl_loss: 2.6149 - recon_loss: 2.1692
# Epoch 169/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 3.7109 - kl_loss: 2.6028 - recon_loss: 2.1492
# Epoch 170/200
# 1830/1830 [==============================] - 0s 76us/step - loss: 3.7297 - kl_loss: 2.6186 - recon_loss: 2.1585
# Epoch 171/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.7380 - kl_loss: 2.6229 - recon_loss: 2.1642
# Epoch 172/200
# 1830/1830 [==============================] - 0s 67us/step - loss: 3.6893 - kl_loss: 2.5745 - recon_loss: 2.1446
# Epoch 173/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.6805 - kl_loss: 2.5418 - recon_loss: 2.1554
# Epoch 174/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.7232 - kl_loss: 2.6114 - recon_loss: 2.1563
# Epoch 175/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.6985 - kl_loss: 2.6065 - recon_loss: 2.1346
# Epoch 176/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 3.7147 - kl_loss: 2.5968 - recon_loss: 2.1567
# Epoch 177/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.7203 - kl_loss: 2.6273 - recon_loss: 2.1439
# Epoch 178/200
# 1830/1830 [==============================] - 0s 77us/step - loss: 3.7308 - kl_loss: 2.6257 - recon_loss: 2.1553
# Epoch 179/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.7205 - kl_loss: 2.5995 - recon_loss: 2.1608
# Epoch 180/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.7101 - kl_loss: 2.5830 - recon_loss: 2.1603
# Epoch 181/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.6956 - kl_loss: 2.6122 - recon_loss: 2.1282
# Epoch 182/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.7305 - kl_loss: 2.6524 - recon_loss: 2.1391
# Epoch 183/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 3.7153 - kl_loss: 2.6360 - recon_loss: 2.1337
# Epoch 184/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 3.7126 - kl_loss: 2.6142 - recon_loss: 2.1441
# Epoch 185/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.7071 - kl_loss: 2.6063 - recon_loss: 2.1433
# Epoch 186/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.6601 - kl_loss: 2.6078 - recon_loss: 2.0954
# Epoch 187/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.6854 - kl_loss: 2.5971 - recon_loss: 2.1271
# Epoch 188/200
# 1830/1830 [==============================] - 0s 75us/step - loss: 3.7013 - kl_loss: 2.6060 - recon_loss: 2.1377
# Epoch 189/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.6525 - kl_loss: 2.6152 - recon_loss: 2.0834
# Epoch 190/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.6868 - kl_loss: 2.5951 - recon_loss: 2.1297
# Epoch 191/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.7043 - kl_loss: 2.5799 - recon_loss: 2.1564
# Epoch 192/200
# 1830/1830 [==============================] - 0s 71us/step - loss: 3.6658 - kl_loss: 2.6020 - recon_loss: 2.1046
# Epoch 193/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.7264 - kl_loss: 2.6264 - recon_loss: 2.1505
# Epoch 194/200
# 1830/1830 [==============================] - 0s 68us/step - loss: 3.7352 - kl_loss: 2.6633 - recon_loss: 2.1372
# Epoch 195/200
# 1830/1830 [==============================] - 0s 72us/step - loss: 3.6772 - kl_loss: 2.6359 - recon_loss: 2.0956
# Epoch 196/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.6502 - kl_loss: 2.5879 - recon_loss: 2.0974
# Epoch 197/200
# 1830/1830 [==============================] - 0s 74us/step - loss: 3.6572 - kl_loss: 2.5982 - recon_loss: 2.0983
# Epoch 198/200
# 1830/1830 [==============================] - 0s 69us/step - loss: 3.6569 - kl_loss: 2.6227 - recon_loss: 2.0833
# Epoch 199/200
# 1830/1830 [==============================] - 0s 73us/step - loss: 3.6633 - kl_loss: 2.5900 - recon_loss: 2.1093
# Epoch 200/200
# 1830/1830 [==============================] - 0s 70us/step - loss: 3.6662 - kl_loss: 2.6017 - recon_loss: 2.1052

# %% [markdown]
# ### Loading model

# %%
#model.load_model(os.path.join(path_out, name_model, 'models'))

# %% [markdown]
# ### Analysis of the latent space

# %%
name_set_plot = 'train'
version = '-v2'

# %%
x_encoded = model.encoder.predict(dataset[name_set_plot]['x'])[0]

# %%
calendar_info = pd.DataFrame(dataset[name_set_plot]['ds'])
calendar_info['month'] = calendar_info.ds.dt.month
calendar_info['weekday'] = calendar_info.ds.dt.weekday
calendar_info['is_weekday'] = (calendar_info.weekday < 5).apply(lambda x:int(x))
calendar_info = pd.merge(calendar_info, holiday_days_df[['ds', 'is_hd']], on='ds', how ='left')
calendar_info.loc[calendar_info['is_hd'].isna(),'is_hd'] = 0

# %%
name_plot = 'z{}_n-{}_beta-{}_train-{}_set-{}_cond-{}{}'.format(str(z_dim),type_scaler,str(beta), name_train, name_set_plot,str(name_type_cond),version)
plot_latent_space_projection(x_proj=x_encoded, calendar_info=calendar_info,
                             path_folder_out=os.path.join(path_out,name_model,'results'), name=name_plot, 
                             pyplot=True, plotly = False)

# %%
temp = get_cond_autoencoder(dataset['train']['ds'], type_cond=['temp'], data_conso_df=data_conso_df)
temp = temp.flatten()

# %%
name_plot = 'temp_z{}_n-{}_beta-{}_train-{}_set-{}_cond-{}{}'.format(str(z_dim),type_scaler,str(beta), name_train, name_set_plot,str(name_type_cond),version)
pyplot_latent_space_projection_temp(x_encoded, calendar_info, temp,os.path.join(path_out,name_model,'results'), name_plot)

# %% [markdown]
# ### Analyse of the reconstruction error

# %%
[x, cond] = dataset['train']['x']
x_hat = model.cvae.predict(x=[x, cond])

# %%
res_mat = (x - x_hat)
res = res_mat.mean(axis=1)

# %%
sn.distplot(res, kde=False, fit=stats.norm, bins=100)

# %%
res_conso_mat = res_mat[:,:48]
res_temp_mat = res_mat[:,48:]

# %%
res_conso = res_conso_mat.mean(axis=1)
res_temp = res_temp_mat.mean(axis=1)

# %%
sn.distplot(res_conso, kde=False, fit=stats.norm, bins=100, label='conso')
sn.distplot(res_temp, kde=False, fit=stats.norm, bins=100, label='temp')
plt.legend()

# %%
results = dict()
results['me'] = {'all': res, 'temp': res_temp, 'conso': res_conso}

# %%
results['mae'] = {
    'all': np.apply_along_axis(lambda x: np.abs(x).mean(),1, res_mat),
    'conso': np.apply_along_axis(lambda x: np.abs(x).mean(),1, res_conso_mat),
    'temp': np.apply_along_axis(lambda x: np.abs(x).mean(),1, res_temp_mat)
}

# %%
results['z_score'] = {}
results['a_score'] = {}

for key, me in results['me'].items():
    z_score = stats.zscore(me)
    a_score = 1-2 * stats.norm.cdf(-np.abs(z_score))
    
    results['z_score'][key] = z_score
    results['a_score'][key] = a_score

# %%
type_error = 'a_score'
type_data = 'all'

name_plot = '{}-{}_z{}_n-{}_beta-{}_train-{}_set-{}_cond-{}{}'.format(type_error, type_data,str(z_dim),type_scaler,str(beta), name_train, name_set_plot,str(name_type_cond),version)
path_plot = os.path.join(path_out,name_model,'results')

error = results[type_error][type_data]
pyplot_latent_space_projection_error(x_encoded, calendar_info, error, color='seismic', path_folder_out=path_plot, name=name_plot)

# %%
sn.distplot(results['z_score']['conso'], kde=False, bins=100, label='conso')
plt.legend()

# %%
sn.distplot(results['a_score']['conso'], kde=False, bins=100, label='conso')
plt.legend()

# %%
sn.distplot(stats.norm.cdf(results['z_score']['conso']), kde=False, bins=100, label='conso')

# %%
indice = 200

# %%
plt.plot(x[indice,])
plt.plot(x_hat[indice,])

# %%
fig, axes = plt.subplots(10,7, figsize=(16,16))

ind = 100

for ax_row in axes:
    for ax in ax_row:
        # create a twin of the axis that shares the x-axis
        # plot some data on each axis.
        ax.plot(x[ind,:])
        ax.plot(x_hat[ind,:],'-r')
        
        ind+=1

plt.tight_layout()
plt.show()

# %%
model.history.keys()
# Out:
# dict_keys(['kl_loss', 'loss', 'recon_loss'])

# %%
el = model.history

# %%
el['kl_loss'][-1]
# Out:
# 1.3353316627564977
